# %%
# %sql

DROP SCHEMA IF EXISTS gold CASCADE;

CREATE DATABASE IF NOT EXISTS gold;


CREATE TABLE IF NOT EXISTS gold.fact_orders
USING DELTA
LOCATION 'abfss://data@oliststorageaccountbth74.dfs.core.windows.net/gold/olist_fact_orders';


CREATE TABLE IF NOT EXISTS gold.fact_order_items
USING DELTA
LOCATION 'abfss://data@oliststorageaccountbth74.dfs.core.windows.net/gold/olist_fact_order_items';


CREATE TABLE IF NOT EXISTS gold.dim_customer
USING DELTA
LOCATION 'abfss://data@oliststorageaccountbth74.dfs.core.windows.net/gold/olist_dim_customers';


CREATE TABLE IF NOT EXISTS gold.dim_product
USING DELTA
LOCATION 'abfss://data@oliststorageaccountbth74.dfs.core.windows.net/gold/olist_dim_products';


CREATE TABLE IF NOT EXISTS gold.dim_seller
USING DELTA
LOCATION 'abfss://data@oliststorageaccountbth74.dfs.core.windows.net/gold/olist_dim_sellers';
